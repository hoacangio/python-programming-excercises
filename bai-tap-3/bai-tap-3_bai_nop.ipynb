# %% [markdown]
# ![image.png](attachment:5814161f-e64f-44c5-bcf7-fa41d97c583a.png)

# %% [markdown]
# ![image.png](attachment:95990a87-e586-479a-919f-31cd7e0d0146.png)

# %% [markdown]
# ![image.png](attachment:3ad06bcd-9206-4ebd-bbef-5e0babf815fa.png)

# %% [markdown]
# ![image.png](attachment:b3a1daff-2231-4d38-afa5-f1ffdca14367.png)

# %% [markdown]
# ![image.png](attachment:077c8a83-8ff7-49a8-ac1a-16d72ef3ba07.png)

# %% [markdown]
# ![image.png](attachment:adb64b6d-3c2f-457d-a9da-fa99dd3aa764.png)
